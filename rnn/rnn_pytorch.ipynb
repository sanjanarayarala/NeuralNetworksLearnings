# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class RNN_model(nn.Module):
    def __init__(self, n_inputs, n_neurons, n_outputs):
        super(RNN_model, self).__init__()
        self.rnn = nn.RNN(input_size= n_inputs, hidden_size=n_neurons, batch_first=True)
        self.fc = nn.Linear(n_neurons, n_outputs)

    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.fc(out[:, -1, :]) #Output of last time step
        return out

# %%
# Hyperparameters
n_inputs = 3  # Input features
n_neurons = 5  # Number of RNN neurons
n_outputs = 2  # Number of classes
learning_rate = 0.01

# Create the model, loss function, and optimizer
model = RNN_model(n_inputs, n_neurons, n_outputs)
loss_fn = nn.CrossEntropyLoss()  # This includes softmax internally
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-3)

# Dummy data (10 samples, 3 features)
X = torch.randn(10, 1, n_inputs)  # 10 samples, 1 time-step, 3 features
y = torch.randint(0, n_outputs, size=(10,))  # 10 target labels (0 or 1)

# Training loop
for epoch in range(100):
    # Zero the gradients
    optimizer.zero_grad()

    # Forward pass
    outputs = model(X)
    loss = loss_fn(outputs, y)

    # Get predictions
    _, predictions = torch.max(outputs, 1)

    # Calculate accuracy
    accuracy = (predictions == y).float().mean()

    # Backward pass
    loss.backward()
    
    # Update weights
    optimizer.step()

    print(f"Epoch: {epoch}, Loss: {loss.item():.4f}, Accuracy: {accuracy:.2f}")
# Out:
# Epoch: 0, Loss: 0.8006, Accuracy: 0.30
# Epoch: 1, Loss: 0.7857, Accuracy: 0.20
# Epoch: 2, Loss: 0.7718, Accuracy: 0.20
# Epoch: 3, Loss: 0.7587, Accuracy: 0.20
# Epoch: 4, Loss: 0.7465, Accuracy: 0.20
# Epoch: 5, Loss: 0.7349, Accuracy: 0.30
# Epoch: 6, Loss: 0.7239, Accuracy: 0.30
# Epoch: 7, Loss: 0.7133, Accuracy: 0.40
# Epoch: 8, Loss: 0.7031, Accuracy: 0.40
# Epoch: 9, Loss: 0.6931, Accuracy: 0.50
# Epoch: 10, Loss: 0.6834, Accuracy: 0.70
# Epoch: 11, Loss: 0.6739, Accuracy: 0.70
# Epoch: 12, Loss: 0.6646, Accuracy: 0.70
# Epoch: 13, Loss: 0.6556, Accuracy: 0.80
# Epoch: 14, Loss: 0.6469, Accuracy: 0.80
# Epoch: 15, Loss: 0.6385, Accuracy: 0.70
# Epoch: 16, Loss: 0.6303, Accuracy: 0.60
# Epoch: 17, Loss: 0.6224, Accuracy: 0.70
# Epoch: 18, Loss: 0.6146, Accuracy: 0.70
# Epoch: 19, Loss: 0.6069, Accuracy: 0.70
# Epoch: 20, Loss: 0.5994, Accuracy: 0.70
# Epoch: 21, Loss: 0.5921, Accuracy: 0.70
# Epoch: 22, Loss: 0.5849, Accuracy: 0.60
# Epoch: 23, Loss: 0.5780, Accuracy: 0.70
# Epoch: 24, Loss: 0.5713, Accuracy: 0.70
# Epoch: 25, Loss: 0.5648, Accuracy: 0.70
# Epoch: 26, Loss: 0.5586, Accuracy: 0.70
# Epoch: 27, Loss: 0.5526, Accuracy: 0.80
# Epoch: 28, Loss: 0.5469, Accuracy: 0.80
# Epoch: 29, Loss: 0.5414, Accuracy: 0.80
# Epoch: 30, Loss: 0.5360, Accuracy: 0.80
# Epoch: 31, Loss: 0.5307, Accuracy: 0.80
# Epoch: 32, Loss: 0.5256, Accuracy: 0.80
# Epoch: 33, Loss: 0.5206, Accuracy: 0.80
# Epoch: 34, Loss: 0.5157, Accuracy: 0.80
# Epoch: 35, Loss: 0.5110, Accuracy: 0.80
# Epoch: 36, Loss: 0.5063, Accuracy: 0.90
# Epoch: 37, Loss: 0.5018, Accuracy: 0.90
# Epoch: 38, Loss: 0.4973, Accuracy: 0.90
# Epoch: 39, Loss: 0.4929, Accuracy: 0.90
# Epoch: 40, Loss: 0.4885, Accuracy: 0.90
# Epoch: 41, Loss: 0.4842, Accuracy: 0.90
# Epoch: 42, Loss: 0.4799, Accuracy: 0.90
# Epoch: 43, Loss: 0.4757, Accuracy: 0.90
# Epoch: 44, Loss: 0.4715, Accuracy: 0.90
# Epoch: 45, Loss: 0.4674, Accuracy: 0.90
# Epoch: 46, Loss: 0.4633, Accuracy: 0.90
# Epoch: 47, Loss: 0.4593, Accuracy: 0.90
# Epoch: 48, Loss: 0.4554, Accuracy: 0.90
# Epoch: 49, Loss: 0.4515, Accuracy: 0.90
# Epoch: 50, Loss: 0.4476, Accuracy: 0.90
# Epoch: 51, Loss: 0.4438, Accuracy: 0.90
# Epoch: 52, Loss: 0.4400, Accuracy: 0.90
# Epoch: 53, Loss: 0.4362, Accuracy: 0.90
# Epoch: 54, Loss: 0.4324, Accuracy: 0.90
# Epoch: 55, Loss: 0.4286, Accuracy: 0.90
# Epoch: 56, Loss: 0.4249, Accuracy: 0.90
# Epoch: 57, Loss: 0.4212, Accuracy: 0.90
# Epoch: 58, Loss: 0.4174, Accuracy: 0.90
# Epoch: 59, Loss: 0.4137, Accuracy: 0.90
# Epoch: 60, Loss: 0.4100, Accuracy: 0.90
# Epoch: 61, Loss: 0.4063, Accuracy: 0.90
# Epoch: 62, Loss: 0.4026, Accuracy: 0.90
# Epoch: 63, Loss: 0.3990, Accuracy: 0.90
# Epoch: 64, Loss: 0.3953, Accuracy: 0.90
# Epoch: 65, Loss: 0.3916, Accuracy: 0.90
# Epoch: 66, Loss: 0.3879, Accuracy: 0.90
# Epoch: 67, Loss: 0.3842, Accuracy: 0.90
# Epoch: 68, Loss: 0.3804, Accuracy: 0.90
# Epoch: 69, Loss: 0.3766, Accuracy: 0.90
# Epoch: 70, Loss: 0.3728, Accuracy: 0.90
# Epoch: 71, Loss: 0.3690, Accuracy: 0.90
# Epoch: 72, Loss: 0.3652, Accuracy: 0.90
# Epoch: 73, Loss: 0.3613, Accuracy: 0.90
# Epoch: 74, Loss: 0.3574, Accuracy: 0.90
# Epoch: 75, Loss: 0.3535, Accuracy: 0.90
# Epoch: 76, Loss: 0.3495, Accuracy: 0.90
# Epoch: 77, Loss: 0.3455, Accuracy: 0.90
# Epoch: 78, Loss: 0.3415, Accuracy: 0.90
# Epoch: 79, Loss: 0.3375, Accuracy: 0.90
# Epoch: 80, Loss: 0.3334, Accuracy: 0.90
# Epoch: 81, Loss: 0.3294, Accuracy: 0.90
# Epoch: 82, Loss: 0.3253, Accuracy: 0.90
# Epoch: 83, Loss: 0.3212, Accuracy: 0.90
# Epoch: 84, Loss: 0.3171, Accuracy: 0.90
# Epoch: 85, Loss: 0.3130, Accuracy: 0.90
# Epoch: 86, Loss: 0.3089, Accuracy: 0.90
# Epoch: 87, Loss: 0.3048, Accuracy: 0.90
# Epoch: 88, Loss: 0.3007, Accuracy: 0.90
# Epoch: 89, Loss: 0.2966, Accuracy: 0.90
# Epoch: 90, Loss: 0.2925, Accuracy: 0.90
# Epoch: 91, Loss: 0.2884, Accuracy: 0.90
# Epoch: 92, Loss: 0.2844, Accuracy: 0.90
# Epoch: 93, Loss: 0.2803, Accuracy: 0.90
# Epoch: 94, Loss: 0.2763, Accuracy: 0.90
# Epoch: 95, Loss: 0.2723, Accuracy: 0.90
# Epoch: 96, Loss: 0.2683, Accuracy: 0.90
# Epoch: 97, Loss: 0.2644, Accuracy: 0.90
# Epoch: 98, Loss: 0.2604, Accuracy: 0.90
# Epoch: 99, Loss: 0.2566, Accuracy: 0.90
